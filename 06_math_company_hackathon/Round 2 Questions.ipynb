# %% [markdown]
# SQL / Python Questions

# %% [markdown]
# Which of the following is correct about Case SQL statement? * <br>
# __It is a way to establish an IF-THEN-ELSE in SQL__ <br>
# It is a way to establish a loop in SQL <Br>
# It is a way to establish a data definition in SQL <br>
# It is a way to establish a data manipulation in SQL <br>
# <br>
# The aggregate functions in SQL are: * <br>
# Mean, SD, Max, Min, Sum <br>
# __Avg,Count,Sum,Max,Min__ <Br>
# Avg, Agg, Median, Mode <br>
# None of the above
#     <br>
# Which of the following SQL commands are examples of aggregate functions? * <br>
# AVERAGE <br>
# COUNT <br>
# __Both A and B__ <Br>
# UPDATE <br>
#     <br>
# The slice and dice operation in SQL can be done by *  <br>
# Projection of columns  <br>
# Selection of rows <br>
# __[Projection and selection](https://stackoverflow.com/questions/1031076/what-are-projection-and-selection)__  <br>
# Select, delete and project  <br>
#     <br>
# Which of the following is the correct SQL Query to delete all rows in a table without deleting the table (structure, attributes, and indexes)? * <br>
# __DELETE FROM table_name;__  <br>
# DELETE TABLE table_name;  <Br>
# DROP TABLE table_name; <br>
# All of the above
#     <br>
# Let X is a column or a combination of columns whose values match a Primary Key in a different table. What is X? * <br>
# Composite Key -- A composite key is made by the combination of two or more columns in a table that can be used to uniquely identify each row in the table when the columns are combined uniqueness of a row is guaranteed, but when it is taken individually it does not guarantee uniqueness, or it can also be understood as a primary key made by the combination of two or more attributes to uniquely identify every row in a table.   <br>
# __Compound Key__ Compound keys are always made up of two or more primary keys from other tables <Br>
# Foreign Key - A foreign key is a column or group of columns in a relational database table that provides a link between data in two tables<Br>
# Non Primary Key <br>
#     <br>
# Which of the following keywords can be used for writing a SQL window functions? * <br>
# Partition  <br>
# Over  <br>
# Rank  <br>
# __All of the above__  <br>
#     <br>
# Which of the following statement(s) is/are correct? *  <br>
# An SQL query automatically eliminates the duplicates  <br>
# An SQL query will not work if there are no indexes on the relations  <br>
# SQL permits attribute names to be repeated in the same relation  <br>
# __None of the above__  <br>
#     <BR>
# Which of the following items are example of unstructured Data? *  <br>
# Credit Card No  <br>
# Text file  <br>
# Audio file <br>
# __Both ii and iii__
#         <br>
# Binning is needed for *  <br>
# Handling the outliers <br>
# Reducing the number of values <br>
# Insights  <br>
# __All of the above__
#             <BR>
# What are the different kinds of windows functions present in SQLite? *  <br>
# Non-Structured  <br>
# Aggregate  <br>
# Built-In <br>
# __Both ii and iii__
#                 <Br>
# Which of the following is not a type of data model? *  <br>
# Conceptual  <br>
# Physical  <br>
# Logical  <br>
# __Permanent__  <br>
#                     <Br>
# Which data model gives the most details about actual database structure? *  <br>
# Conceptual  <br>
# __Physical__  <br>
# Logical  <br>
# Permanent
#                         <BR>
# Down sampling is required *  <br>
# When the minority class is small  <br>
# When small data is available  <br>
# __When large data is available__  <br>
# When population is unknown
#                             <br>
# What are the different relations that can exist in the data? * <br>
# Linear and non linear  <br>
# Linear and independent  <br>
# __Linear, non-linear and independent__  <br>
# Non-linear and independent <br>

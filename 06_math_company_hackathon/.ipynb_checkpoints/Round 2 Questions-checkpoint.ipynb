# %% [markdown]
# SQL / Python Questions

# %% [markdown]
# Which of the following is correct about Case SQL statement? * <br>
# __It is a way to establish an IF-THEN-ELSE in SQL__ <br>
# It is a way to establish a loop in SQL <Br>
# It is a way to establish a data definition in SQL <br>
# It is a way to establish a data manipulation in SQL <br>
# <br>
# The aggregate functions in SQL are: * <br>
# Mean, SD, Max, Min, Sum <br>
# __Avg,Count,Sum,Max,Min__ <Br>
# Avg, Agg, Median, Mode <br>
# None of the above
#     <br>
# Which of the following SQL commands are examples of aggregate functions? * <br>
# AVERAGE <br>
# COUNT <br>
# __Both A and B__ <Br>
# UPDATE <br>
#     <br>
# The slice and dice operation in SQL can be done by *  <br>
# Projection of columns  <br>
# Selection of rows <br>
# __[Projection and selection](https://stackoverflow.com/questions/1031076/what-are-projection-and-selection)__  <br>
# Select, delete and project  <br>
#     <br>
# Which of the following is the correct SQL Query to delete all rows in a table without deleting the table (structure, attributes, and indexes)? *
# DELETE FROM table_name;
# DELETE TABLE table_name;
# DROP TABLE table_name;
# All of the above
#     <br>
# Let X is a column or a combination of columns whose values match a Primary Key in a different table. What is X? *
# Composite Key
# Compound Key
# Foreign Key
# Non Primary Key
#     <br>
# Which of the following keywords can be used for writing a SQL window functions? *
# Partition
# Over
# Rank
# All of the above
# Which of the following statement(s) is/are correct? *
# An SQL query automatically eliminates the duplicates
# An SQL query will not work if there are no indexes on the relations
# SQL permits attribute names to be repeated in the same relation
# None of the above
# Which of the following items are example of unstructured Data? *
# Credit Card No
# Text file
# Audio file
# Both ii and iii
# Binning is needed for *
# Handling the outliers
# Reducing the number of values
# Insights
# All of the above
# What are the different kinds of windows functions present in SQLite? *
# Non-Structured
# Aggregate
# Built-In
# Both ii and iii
# Which of the following is not a type of data model? *
# Conceptual
# Physical
# Logical
# Permanent
# Which data model gives the most details about actual database structure? *
# Conceptual
# Physical
# Logical
# Permanent
# Down sampling is required *
# When the minority class is small
# When small data is available
# When large data is available
# When population is unknown
# What are the different relations that can exist in the data? *
# Linear and non linear
# Linear and independent
# Linear, non-linear and independent
# Non-linear and independentWhich of the following is correct about Case SQL statement? *
# It is a way to establish an IF-THEN-ELSE in SQL
# It is a way to establish a loop in SQL
# It is a way to establish a data definition in SQL
# It is a way to establish a data manipulation in SQL
# The aggregate functions in SQL are: *
# Mean, SD, Max, Min, Sum
# Avg, Count, Sum, Max, Min
# Avg, Agg, Median, Mode
# None of the above
# Which of the following SQL commands are examples of aggregate functions? *
# AVERAGE
# COUNT
# Both A and B
# UPDATE
# The slice and dice operation in SQL can be done by *
# Projection of columns
# Selection of rows
# Projection and selection
# Select, delete and project
# Which of the following is the correct SQL Query to delete all rows in a table without deleting the table (structure, attributes, and indexes)? *
# DELETE FROM table_name;
# DELETE TABLE table_name;
# DROP TABLE table_name;
# All of the above
# Let X is a column or a combination of columns whose values match a Primary Key in a different table. What is X? *
# Composite Key
# Compound Key
# Foreign Key
# Non Primary Key
# Which of the following keywords can be used for writing a SQL window functions? *
# Partition
# Over
# Rank
# All of the above
# Which of the following statement(s) is/are correct? *
# An SQL query automatically eliminates the duplicates
# An SQL query will not work if there are no indexes on the relations
# SQL permits attribute names to be repeated in the same relation
# None of the above
# Which of the following items are example of unstructured Data? *
# Credit Card No
# Text file
# Audio file
# Both ii and iii
# Binning is needed for *
# Handling the outliers
# Reducing the number of values
# Insights
# All of the above
# What are the different kinds of windows functions present in SQLite? *
# Non-Structured
# Aggregate
# Built-In
# Both ii and iii
# Which of the following is not a type of data model? *
# Conceptual
# Physical
# Logical
# Permanent
# Which data model gives the most details about actual database structure? *
# Conceptual
# Physical
# Logical
# Permanent
# Down sampling is required *
# When the minority class is small
# When small data is available
# When large data is available
# When population is unknown
# What are the different relations that can exist in the data? *
# Linear and non linear
# Linear and independent
# Linear, non-linear and independent
# Non-linear and independent
